# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Crop_Recommendation.csv")

# %%
df.head()
# Out:
#     N   P   K  Temperature   Humidity        ph    Rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   Temperature  2200 non-null   float64
#  4   Humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   Rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# Temperature    0
# Humidity       0
# ph             0
# Rainfall       0
# label          0
# dtype: int64

# %%
df.describe()
# Out:
#                  N            P            K  Temperature     Humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     Rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
num_df=df.select_dtypes('number')

# %%
num_df
# Out:
#         N   P   K  Temperature   Humidity        ph    Rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
cor=num_df.corr()

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
for i in num_df.columns:
    plt.figure(figsize=(8,10))
    sns.displot(num_df,x=i,kde=True)
    plt.title(f'Histogram for {i}')
    plt.xlabel(i)
    plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
for i in num_df.columns:
    plt.figure(figsize=(8,6))
    sns.boxplot(num_df,x=i)
    plt.title(f'Boxplot for {i}')
    plt.xlabel(i)
    plt.show()

# %%
plt.figure(figsize=(10, 8))
j=1
for i in num_df.columns:
    plt.subplot(4,3,j)
    sns.histplot(num_df,x=i,kde=True)
    plt.title(f'Distribution of {i}')   
    j+=1
      
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
j=1
for i in num_df.columns:
    plt.subplot(4,3,j)
    sns.boxplot(num_df,x=i)
    plt.title(f'Distribution of {i}')   
    j+=1
      
plt.tight_layout()
plt.show()

# %%
for i in num_df.columns:
    plt.figure(figsize=(8, 6))
    sns.barplot(x=num_df[i], y=df['label'])
    plt.title(f'Crop vs {i}')
    plt.ylabel('Crops')
    plt.show()

# %%
for i in num_df.columns:
    plt.figure(figsize=(8, 6))
    plt.barh(df['label'], num_df[i])
    plt.title(f'Crop vs {i}')
    plt.ylabel('Crops')
    plt.xlabel(i)
    plt.show()

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df,hue='label')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## LabelEncoding

# %%
labels={
    'rice':0,
    'maize':1,
    'jute':2,
    'cotton':3,
    'coconut':4,
    'papaya':5,
    'orange':6,
    'apple':7,
    'muskmelon':8,
    'watermelon':9,
    'grapes':10,
    'mango':11,
    'banana':12,
    'pomegranate':13,
    'lentil':14,
    'blackgram':15,
    'mungbean':16,
    'mothbeans':17,
    'pigeonpeas':18,
    'kidneybeans':19,
    'chickpea':20,
    'coffee':21
    
}
df['label']=df['label'].map(labels)

# %%
df['label'].value_counts()
# Out:
# label
# 0     100
# 1     100
# 2     100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 8     100
# 9     100
# 10    100
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# 16    100
# 17    100
# 18    100
# 19    100
# 20    100
# 21    100
# Name: count, dtype: int64

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# lb=LabelEncoder()
# y=lb.fit_transform(y)

# %% [markdown]
# ## Train_Test_split

# %%
x=df.drop(columns=['label'])
y=df['label']

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2)

# %%
train_x
# Out:
#         N   P   K  Temperature   Humidity        ph    Rainfall
# 18     77  38  36    21.865252  80.192301  5.953933  224.555017
# 367    37  65  16    22.835202  18.972675  5.683548   63.592767
# 1982  108  60  17    22.758057  76.757684  6.558903   97.766006
# 1301  119  19  55    25.187800  83.446217  6.818261   46.874209
# 1763   70  65  52    30.420121  93.126598  6.583529   75.952950
# ...   ...  ..  ..          ...        ...       ...         ...
# 882    14  74  15    27.999903  65.576534  6.493037   49.940431
# 1625   30   7  15    33.234533  91.060539  7.825532  115.765990
# 1622    8   7  10    28.262049  91.983174  6.929216  105.213226
# 337     6  62  22    20.530527  18.092240  5.824091  120.450929
# 1366  120   7  47    24.247825  83.036879  6.653868   54.765762
#
# [1760 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %% [markdown]
# ## Logistic Regression

# %%
lr=LogisticRegression(max_iter=10000)
lr.fit(train_x,train_y)
y_pred=lr.predict(test_x)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
lr.score(test_x,test_y)
# Out:
# 0.990909090909091

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.990909090909091

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier()
knc.fit(train_x,train_y)
y_pred=knc.predict(test_x)

# %%
knc.score(train_x,train_y)
# Out:
# 0.9880681818181818

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9772727272727273

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(train_x,train_y)
rfc_pred=rfc.predict(test_x)

# %%
rfc.score(test_x,test_y)
# Out:
# 0.9977272727272727

# %%
accuracy_score(test_y, rfc_pred)
# Out:
# 0.9977272727272727

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(train_x,train_y)
dtc_pred=dtc.predict(test_x)

# %%
dtc.score(test_x,test_y)
# Out:
# 0.990909090909091

# %%
accuracy_score(test_y, dtc_pred)
# Out:
# 0.990909090909091

# %% [markdown]
# ## naive_bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nbg = GaussianNB()
nbg.fit(train_x,train_y)
nbg_pred= nbg.predict(test_x)

# %%
nbg.score(test_x,test_y)
# Out:
# 0.9977272727272727

# %%
accuracy_score(test_y, nbg_pred)
# Out:
# 0.9977272727272727

# %% [markdown]
# ## svm

# %%
from sklearn.svm import SVC

# %%
svc = SVC()  
svc.fit(train_x, train_y)  

y_pred = svc.predict(test_x)

# %%
svc.score(test_x,test_y)
# Out:
# 0.9772727272727273

# %%
accuracy_score(test_y,y_pred)
# Out:
# 0.9772727272727273

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
train_xss = sc.fit_transform(train_x)
test_xss = sc.fit_transform(test_x)

# %%
train_y
# Out:
# 18       0
# 367     19
# 1982     3
# 1301     9
# 1763     5
#         ..
# 882     14
# 1625     6
# 1622     6
# 337     19
# 1366     9
# Name: label, Length: 1760, dtype: int64

# %% [markdown]
# ## XGBClassifier(stdscaler)

# %%
from xgboost import XGBClassifier
#bst = XGBClassifier()
bst = XGBClassifier(n_estimators=5, max_depth=5, learning_rate=1, objective='multinomial:logistic')
bst.fit(train_xss, train_y)
# make predictions
y_pred = bst.predict(test_xss)

# %%
accuracy_score(test_y, y_pred)
# Out:
# 0.9113636363636364

# %% [markdown]
# ## LogisticRegression (stdscaler)

# %%
lr=LogisticRegression(max_iter=10000)
lr.fit(train_xss,train_y)
y_pred=lr.predict(test_xss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 lr=LogisticRegression(max_iter=10000)
#       2 lr.fit(train_xss,train_y)
#       3 y_pred=lr.predict(test_xss)
#
# NameError: name 'LogisticRegression' is not defined

# %%
accuracy_score(test_y, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 accuracy_score(test_y, y_pred)
#
# NameError: name 'accuracy_score' is not defined

# %% [markdown]
# ## DecisionTree (stdscaler)

# %%
dtc2=DecisionTreeClassifier()
dtc2.fit(train_xss,train_y)
y_pred=dtc2.predict(test_xss)

# %%
dtc2.score(test_xss,test_y)
# Out:
# 0.9590909090909091

# %%
accuracy_score(test_y, y_pred)
# Out:
# 0.9590909090909091

# %% [markdown]
# ## Naive Bayes(stdscaler)

# %%
nbg2 = GaussianNB()
nbg2.fit(train_xss,train_y)
nbg2_pred= nbg2.predict(test_xss)

# %%
nbg2.score(test_xss,test_y)
# Out:
# 0.9931818181818182

# %%
accuracy_score(test_y, nbg2_pred)
# Out:
# 0.9931818181818182

# %% [markdown]
# ## Meta model

# %%
X_val_meta = np.column_stack((rfc_pred,dtc_pred, nbg_pred))
y_val=np.column_stack(test_y)
# Train the meta-model on the combined feature matrix and the target values
meta_model = DecisionTreeClassifier()
meta_model.fit(X_val_meta,test_y)
# Out:
# DecisionTreeClassifier()

# %%
len(X_val_meta)
# Out:
# 440

# %%
len(test_y)
# Out:
# 440

# %%
m_pred=meta_model.predict(X_val_meta)

# %%
accuracy_score(test_y, m_pred)
# Out:
# 0.9977272727272727

# %%
cm = confusion_matrix(test_y, m_pred)
sns.heatmap(cm, annot=True,cmap="cubehelix") 
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.ylabel('True')
plt.show()

# %%
def recomm(N,P,K,Temp,Hum,ph,Rain):
#     features=np.array([[N,P,K,Temp,Hum,ph,Rain]])
    features = pd.DataFrame([[N, P, K, Temp, Hum, ph, Rain]], columns=['N', 'P', 'K', 'Temperature', 'Humidity', 'ph', 'Rainfall'])

    rfc_pred=rfc.predict(features)
    dtc_pred=dtc.predict(features)
    nbg_pred= nbg.predict(features)

    X_val_meta = np.column_stack((rfc_pred,dtc_pred, nbg_pred))
    
    pred=meta_model.predict(X_val_meta)
    return pred[0]

# %%
import pickle

# %%
pickle.dump(rfc,open('model1.pkl','wb'))

# %%
pickle.dump(dtc,open('model2.pkl','wb'))

# %%
pickle.dump(nbg,open('model3.pkl','wb'))

# %%
pickle.dump(meta_model,open('meta_model.pkl','wb'))
